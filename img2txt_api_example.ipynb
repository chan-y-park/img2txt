# %% [markdown]
# # Training

# %% [markdown]
# ## Prepare training and validation datasets.

# %%
from dataset import MSCOCO, Vocabulary

# %%
dataset_path = '../datasets/'
ms_coco_train_caption_file = (
    dataset_path + 'ms_coco/annotations/captions_train2014.json'
) 
ms_coco_train_image_dir = (
    dataset_path + 'ms_coco/train2014/'
)
training_dataset = MSCOCO(
    caption_file=ms_coco_train_caption_file,
    image_dir=ms_coco_train_image_dir,
)

# %%
training_dataset.get_size()
# Out:
# 414113

# %%
ms_coco_val_caption_file = (
    dataset_path + 'ms_coco/annotations/captions_val2014.json'
) 
ms_coco_val_image_dir = (
    dataset_path + 'ms_coco/val2014/'
)
validation_dataset = MSCOCO(
    caption_file=ms_coco_val_caption_file,
    image_dir=ms_coco_val_image_dir,
)

# %%
validation_dataset.get_size()
# Out:
# 202654

# %% [markdown]
# ## Build vocabulary from the training dataset.

# %%
vocabulary = Vocabulary(
    min_word_count=3,
    dataset=training_dataset,
)

# %%
vocabulary.get_size()
# Out:
# 11498

# %%
vocabulary.save('ms_coco_vocabulary.json')

# %% [markdown]
# ## Train the model.

# %%
from model import Image2Text

# %%
img2txt = Image2Text(
    training_dataset=training_dataset,
    validation_dataset=validation_dataset,
    vocabulary_file_path='ms_coco_vocabulary.json',
    config_file_path='default_config.json',
)
# Out:
# INFO:tensorflow:Restoring parameters from pretrained/inception_v3.ckpt

# %%
rd = img2txt.train(
    max_num_steps=10 ** 2,
)
# Out:
# Training for 100 steps, total training 100 steps (= 0.00772736 epochs).
# 0% : minibatch_loss = 9.35499
# Image predictions
# American_black_bear: 0.915226
# sloth_bear: 0.0210429
# brown_bear: 0.00383691
# harmonica: 0.000695948
# American_coot: 0.000481433
# input: a black bear walking through a forest filled with trees .
# output: modular breaking heap perfectly timber hike modular perfectly squatting patrolling searching costumes patrolling creates mattresses unloads pyramids undone hike effect british workspace condiment hike hoody tale part bruised pyramids checking clothed part loosely class checking swans murals searching chariot murals searching chariot murals searching chariot murals searching chariot murals searching chariot murals searching chariot murals searching chariot murals searching chariot
#
#
# WARNING:tensorflow:Error encountered when serializing __tensorboard_plugin_asset__tensorboard_text.
# Type is unsupported, or the types of the items don't match field type in CollectionDef.
# 'TextSummaryPluginAsset' object has no attribute 'name'
# checkpoint saved at 0822_021734/img2txt-0
# 1% : minibatch_loss = 9.26651
# Image predictions
# stretcher: 0.23744
# wardrobe: 0.0869261
# bassinet: 0.0787937
# cradle: 0.0329098
# studio_couch: 0.0302461
# input: a bunch of items that are on a bed .
# output: a <eos> . a . <eos> a <eos> . a . <eos> a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> .
#
#
# 2% : minibatch_loss = 9.1621
# Image predictions
# vase: 0.636529
# pitcher: 0.181699
# water_jug: 0.00909304
# chime: 0.00770989
# whiskey_jug: 0.00417991
# input: black mediterranean vase with brown vines , in from on wall with earth style art work .
# output: a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> .
#
#
# 3% : minibatch_loss = 8.99868
# Image predictions
# crash_helmet: 0.905995
# motor_scooter: 0.0362322
# moped: 0.0052393
# disk_brake: 0.00268784
# sports_car: 0.00246142
# input: a man in a helmet taking a sharp turn on a motorcycle .
# output: a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> .
#
#
# 4% : minibatch_loss = 8.63539
# Image predictions
# rugby_ball: 0.747471
# unicycle: 0.0557055
# soccer_ball: 0.0312534
# volleyball: 0.0227276
# basketball: 0.0205999
# input: a man tries to block his opponent from catching a frisbee .
# output: a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> .
#
#
# 5% : minibatch_loss = 8.27854
# Image predictions
# backpack: 0.514319
# loudspeaker: 0.0361502
# vacuum: 0.0204211
# home_theater: 0.0140378
# purse: 0.0088918
# input: a close up of two luggage bags on the ground
# output: a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> .
#
#
# 6% : minibatch_loss = 9.35007
# Image predictions
# amphibian: 0.333618
# school_bus: 0.275849
# fire_engine: 0.049378
# minibus: 0.0491992
# minivan: 0.00770691
# input: two old looking buses and a brightly colored truck on a paved road .
# output: <eos> . on <eos> . on <eos> . on <eos> . on <eos> . on <eos> . on <eos> . on <eos> . on <eos> . on <eos> . on <eos> . on <eos> . on <eos> . on <eos> . on <eos> . on <eos> . on <eos> . on <eos> . on <eos> . on
#
#
# 7% : minibatch_loss = 8.51761
# Image predictions
# ballplayer: 0.887686
# baseball: 0.0998743
# football_helmet: 0.000689061
# knee_pad: 0.000164519
# scoreboard: 0.000145956
# input: the player in an orange shirt is preparing to swing a bat .
# output: a the on a <eos> . a <eos> . <eos> . a <eos> . on <eos> . on <eos> . on <eos> . on <eos> . on <eos> . on <eos> . the <eos> . on <eos> . on <eos> . on <eos> . on <eos> . on <eos> . on <eos> . on <eos> . on <eos> . on
#
#
# 8% : minibatch_loss = 8.59193
# Image predictions
# sunglass: 0.0944682
# sunglasses: 0.0725515
# drumstick: 0.0613381
# steel_drum: 0.0429257
# fountain: 0.0374084
# input: a young man on a skateboard doing tricks .
# output: a in of a <eos> . a <eos> . <eos> . in <eos> . in <eos> . on <eos> . in <eos> . on <eos> . on <eos> . the <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a
#
#
# 9% : minibatch_loss = 13.2288
# Image predictions
# throne: 0.187473
# lampshade: 0.0567078
# medicine_chest: 0.0430072
# vestment: 0.0421776
# window_shade: 0.0350102
# input: a bathroom with a red sink next to a red toilet .
# output: a <eos> shirted <eos> a wooded <eos> a outer <eos> plumbing adjustable <eos> adjacent postal <eos> . the . the on . the on . on the . on the a . in a in of a walk-in measure . a on . a on . a on . a on . a on . a on . a on . a on . a on
#
#
# 10% : minibatch_loss = 9.62163
# Image predictions
# violin: 0.0921458
# flute: 0.0739647
# abaya: 0.0697553
# harp: 0.0636009
# cornet: 0.048379
# input: a man sitting on brick steps next to a wall .
# output: . the on . a on a of in . the in . on the a . the . a <eos> . <eos> the . <eos> the . <eos> the <eos> . a <eos> . the . a on . a on . a on . a on . a on . a on . a on . a on . a on . a on . a on . a on . a on . a on . a on . a on . a on . a on . a on . a on . a on . a on . a on . a on . a on . a on . a on . a on . a on . a on
#
#
# WARNING:tensorflow:Error encountered when serializing __tensorboard_plugin_asset__tensorboard_text.
# Type is unsupported, or the types of the items don't match field type in CollectionDef.
# 'TextSummaryPluginAsset' object has no attribute 'name'
# checkpoint saved at 0822_021734/img2txt-10
# 11% : minibatch_loss = 8.49981
# Image predictions
# parachute: 0.842488
# lakeside: 0.0327771
# balloon: 0.0321856
# bearskin: 0.0104689
# flagpole: 0.00638054
# input: two people are flying a kite at the park
# output: . a on a . of a of in a . on a . on a . the a . <eos> <eos> . on <eos> . on <eos> . the . a on . a on . a on . a on . a on . a on . a on . a on . a on . a on . a on . a on
#
#
# 12% : minibatch_loss = 8.00272
# Image predictions
# stethoscope: 0.74422
# iPod: 0.0877197
# pay-phone: 0.0216204
# hand_blower: 0.0138606
# dumbbell: 0.00938655
# input: a man and woman standing near each other with remotes .
# output: a in of a in of a in of a in of a in of a in of a of in a of the a of in a . of a . of a . <eos> . a on . a on . a on . a on . a on . a on
#
#
# 13% : minibatch_loss = 12.5416
# Image predictions
# rugby_ball: 0.144399
# croquet_ball: 0.0402917
# lawn_mower: 0.033375
# baseball: 0.0320674
# soccer_ball: 0.0319946
# input: a woman sitting on the grass next to a hydrant .
# output: . a <eos> . <eos> on <eos> . on <eos> . the <eos> . the <eos> . on <eos> . the <eos> . the <eos> . the <eos> . urban <eos> . a a yogurt tomatoes . a on . a on . a on . a on
#
#
# 14% : minibatch_loss = 9.72433
# Image predictions
# Band_Aid: 0.336176
# matchstick: 0.206794
# pill_bottle: 0.138969
# butternut_squash: 0.0689
# dough: 0.0405794
# input: a person chops carrots into cubes on a wooden cutting board .
# output: a of the the of on a . the . a the a . the a . the a . the a . the a . the a . of . a the a . the a . the . a on . a on . a on . a on . a on . a on . a on . a on . a on . a on . a on . a on
#
#
# 15% : minibatch_loss = 10.4365
# Image predictions
# alp: 0.699817
# dogsled: 0.0765464
# valley: 0.0154225
# mountain_tent: 0.0129549
# ski: 0.00990667
# input: a group of eight cross country skiers moving in a straight line .
# output: a of in a . on . a on . a on . a in . <eos> a <eos> . a <eos> hooded cook <eos> person dicing <eos> two person the on of the on in . a in . a in . a on . a on . a on . a on . a on . a on
#
#
# 16% : minibatch_loss = 7.99008
# Image predictions
# television: 0.511271
# screen: 0.130935
# monitor: 0.0266228
# desk: 0.0264971
# desktop_computer: 0.0208497
# input: this bedroom has a large bed and a small tv at the end of the bed
# output: a of in of . on . a in a . in a . on a . on a . on a . on a . in a . in a . on a . on a . on a . in a . in . in on a . on a . on a . on
#
#
# 17% : minibatch_loss = 7.79149
# Image predictions
# sorrel: 0.284867
# ox: 0.121398
# plow: 0.105959
# worm_fence: 0.0980524
# seashore: 0.0151403
# input: a couple of horses stopped in tracks on beach near he ocean .
# output: a of in a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . on a . on a . on a . on
#
#
# 18% : minibatch_loss = 9.6791
# Image predictions
# quilt: 0.419531
# sleeping_bag: 0.321582
# studio_couch: 0.021752
# crib: 0.017026
# mosquito_net: 0.00889141
# input: an unmade bed with blue and white sheets in daylight
# output: <eos> of on on in of on . in on <eos> . <eos> . on <eos> on in <eos> on . <eos> on . <eos> on . <eos> on . <eos> on . . a on . a on . a on . a on . a on . a on . a on
#
#
# 19% : minibatch_loss = 7.98716
# Image predictions
# miniskirt: 0.279681
# bath_towel: 0.069206
# scale: 0.0546206
# sock: 0.037415
# Band_Aid: 0.0307804
# input: a woman placing her finger with <unk> ring on her knee .
# output: a of in . in of . in of . of in . in of . in of . in of . in of . in the . in of . in of . in of . in of . a in . a in . a in . a in . a in . a in
#
#
# 20% : minibatch_loss = 7.43646
# Image predictions
# broccoli: 0.998267
# cauliflower: 0.000446282
# diamondback: 9.29209e-05
# zucchini: 8.5146e-05
# meat_loaf: 8.09916e-05
# input: a very tasty looking dish with some pasta and broccoli .
# output: a of two of the . . the of . in of . the of . the of . the on . the on . the in . the of . the in . the on . a on . a on . a on . a on . a on . a on
#
#
# WARNING:tensorflow:Error encountered when serializing __tensorboard_plugin_asset__tensorboard_text.
# Type is unsupported, or the types of the items don't match field type in CollectionDef.
# 'TextSummaryPluginAsset' object has no attribute 'name'
# checkpoint saved at 0822_021734/img2txt-20
# 21% : minibatch_loss = 6.83043
# Image predictions
# vase: 0.126785
# soap_dispenser: 0.0771973
# digital_clock: 0.0655667
# scale: 0.0472179
# pot: 0.0372491
# input: a table with an alarm clock on top of it .
# output: a of and of and the of . on . on of <eos> . and <eos> . on <eos> . the <eos> . and <eos> . and <eos> . on <eos> . and <eos> . on a . on a . on a . on
#
#
# 22% : minibatch_loss = 6.40471
# Image predictions
# freight_car: 0.823656
# electric_locomotive: 0.110001
# steam_locomotive: 0.00899696
# passenger_car: 0.00412718
# viaduct: 0.000645467
# input: a train that is sitting on the track .
# output: a of in of the in . the of . the of . the a . a the . the in . the <eos> . <eos> the . a the a . on a . on a . on a . on a . on a . on a . on a . on a . on a . on
#
#
# 23% : minibatch_loss = 7.32082
# Image predictions
# brambling: 0.836228
# goldfinch: 0.0738882
# robin: 0.0179305
# water_ouzel: 0.00299488
# jacamar: 0.00165434
# input: a colorful bird is sitting among the tree branches .
# output: a <eos> of a on the a on <eos> a <eos> on <eos> a on <eos> a on <eos> a on <eos> a on <eos> a on a <eos> on <eos> a on a . on a . on a . on a . on a . on a . on a . on a . on
#
#
# 24% : minibatch_loss = 8.00596
# Image predictions
# ski: 0.977028
# puck: 0.00317301
# ski_mask: 0.00246566
# snowmobile: 0.000931039
# alp: 0.000694767
# input: small child in a snowsuit and helmet on a ski hill .
# output: a of the of on the on of . on the of on the in on the in on the . on the . on the . on the . on . the on . the on the . . a on . a on . a on . a on . a on . a on . a on . a on
#
#
# 25% : minibatch_loss = 7.26658
# Image predictions
# hotdog: 0.630266
# cheeseburger: 0.23243
# bagel: 0.0342533
# conch: 0.021818
# ice_cream: 0.0051958
# input: a person eating a pastry covered in peanut butter .
# output: a two man of in the . of in . in on . in on . in on . in the . in on . in the . in on . in on a . on a . on a . on a . on a . on a . on
#
#
# 26% : minibatch_loss = 6.98686
# Image predictions
# tabby: 0.62407
# tiger_cat: 0.155385
# Egyptian_cat: 0.0837343
# toilet_seat: 0.00909384
# washbasin: 0.00829548
# input: a cat with big eyes sitting on a bathroom sink
# output: a two man of the on on of . on . of . on the on . the . on the . on the . the on . on the . on the a . on a . on a . on a . on a . on a . on a . on a . on a . on
#
#
# 27% : minibatch_loss = 6.16165
# Image predictions
# Siamese_cat: 0.552988
# lynx: 0.225409
# Egyptian_cat: 0.0738297
# window_screen: 0.0315418
# prison: 0.0301072
# input: a white cat with blue eyes perched on window bars .
# output: a man two of on the of on a a on of a on of a on in . a on a . on a . on a . on . on a . a on a . on a . on a . on a . on a . on a . on a . on
#
#
# 28% : minibatch_loss = 6.5438
# Image predictions
# bathtub: 0.482328
# tub: 0.459453
# washbasin: 0.0267234
# consomme: 0.00342853
# shower_curtain: 0.00124875
# input: a sink filled with soapy water and a yellow rubber ducky
# output: a of two of on a of on . a of . a <eos> of <eos> . of . <eos> of <eos> . of <eos> . of <eos> . of <eos> . of <eos> . of a . on a . on a . on a . on a . on a . on
#
#
# 29% : minibatch_loss = 6.96469
# Image predictions
# ballplayer: 0.699987
# baseball: 0.292349
# scoreboard: 0.000281842
# parachute: 0.000150768
# football_helmet: 0.000123367
# input: a man playing baseball in the middle of a pitch
# output: a two man on of in a on of a on in a on in a on in a on in a on in a on in a on . a on . a . on a . on a . on a . on a . on
#
#
# 30% : minibatch_loss = 7.16897
# Image predictions
# miniature_pinscher: 0.306704
# Doberman: 0.255006
# toy_terrier: 0.228705
# kelpie: 0.00721339
# Chihuahua: 0.00364853
# input: a dog with a frisbee in his mouth .
# output: a two man of on is . of on . on of . on in . on in . on in . on in . on in . on in . a on . a on . a on . a on . a on . a on . a on . a on . a on . a on . a on . a on . a on . a on
#
#
# WARNING:tensorflow:Error encountered when serializing __tensorboard_plugin_asset__tensorboard_text.
# Type is unsupported, or the types of the items don't match field type in CollectionDef.
# 'TextSummaryPluginAsset' object has no attribute 'name'
# checkpoint saved at 0822_021734/img2txt-30
# 31% : minibatch_loss = 6.77087
# Image predictions
# notebook: 0.756767
# laptop: 0.199474
# modem: 0.0057395
# screen: 0.00230361
# space_bar: 0.00220155
# input: a person sits next to a laptop on the wooden table .
# output: a two man man is the on the of on the in the on in the on in the on in on in the on the in on the in on the in on the in on the in a . on a . on a . on a . on a . on a . on a . on a . on a . on a . on
#
#
# 32% : minibatch_loss = 6.41415
# Image predictions
# vase: 0.502817
# bee: 0.037747
# paintbrush: 0.0287065
# pitcher: 0.0262105
# sea_slug: 0.0250666
# input: a painting of a vase with a polka dot gray background .
# output: a two man a man is of on with a on with a with of a on with on the in a on with the with on on the in a on the on the with a <eos> the a . on a . on a . on a . on a . on a . on
#
#
# 33% : minibatch_loss = 5.92991
# Image predictions
# hummingbird: 0.278915
# junco: 0.0943201
# robin: 0.0788815
# bulbul: 0.0446164
# water_ouzel: 0.0302498
# input: a very small bird with a long beak sitting on a branch
# output: a two man a man of of on the a on of a <eos> on <eos> a the <eos> a the <eos> a the <eos> a . <eos> a . <eos> a . <eos> a . <eos> a . a . on a . on a . on a . on a . on
#
#
# 34% : minibatch_loss = 6.01225
# Image predictions
# ski: 0.790023
# library: 0.0241621
# alp: 0.0112278
# jinrikisha: 0.00701622
# palace: 0.00631532
# input: people riding their skis at a ski slope near a building
# output: a two man of man is of a on a of on a . of . a on . a on . a on . a on . a on . <eos> a . a <eos> a . on a . on a . on a . on
#
#
# 35% : minibatch_loss = 6.10041
# Image predictions
# pizza: 0.561546
# ice_lolly: 0.0675821
# trifle: 0.0581405
# spatula: 0.0262228
# lipstick: 0.0219346
# input: a man is holding a piece of cake on a plate and he has some on his face .
# output: a two man man is of of on is a of on a <eos> of <eos> a of <eos> a on <eos> on a <eos> a on <eos> a on <eos> a on <eos> a on <eos> a . <eos> a on <eos> . on <eos> on . <eos> a on <eos> . on <eos> a . <eos> a on
#
#
# 36% : minibatch_loss = 6.06845
# Image predictions
# pizza: 0.628296
# burrito: 0.0433287
# dough: 0.0432226
# potpie: 0.0243756
# cheeseburger: 0.00940027
# input: a person assembling a homemade cheese pizza on wax paper .
# output: a two man man is of a on of a on of a on of a on . a . on a . on a . on a . on a . on a . on a . on a . on a . on a . on a . on a . on a . on a . on a . on a . on a . on a . on a . on a . on a . on
#
#
# 37% : minibatch_loss = 6.10116
# Image predictions
# toilet_seat: 0.990526
# plunger: 0.00327518
# toilet_tissue: 0.00273578
# washbasin: 0.00010327
# sewing_machine: 7.77048e-05
# input: a white toilet in a restroom with a metal flushing mechanism .
# output: a two man man of is of in on in of the in . of . in <eos> . in <eos> . <eos> in . <eos> in . <eos> in . <eos> in . <eos> in . <eos> in a . in a . in a . in a . in a . in a . in a . in a . in a . in a . in a . in a . in a . in a . in a . in a . in
#
#
# 38% : minibatch_loss = 5.70099
# Image predictions
# brown_bear: 0.932378
# American_black_bear: 0.00701112
# ice_bear: 0.00276871
# sloth_bear: 0.00209046
# lesser_panda: 0.000644045
# input: a defensive looking bear hovering over its baby cubs .
# output: a two man man is of of on in of a on a of on a <eos> of <eos> a on <eos> a on <eos> of a <eos> a on <eos> a on a . on a . on a . on a . on
#
#
# 39% : minibatch_loss = 5.87733
# Image predictions
# jigsaw_puzzle: 0.404455
# pajama: 0.0230973
# guinea_pig: 0.0205705
# Christmas_stocking: 0.0143306
# mouse: 0.0132147
# input: three children sit at a table together doing crafts
# output: a two man a man is of on in a of on a . on a . <eos> . a <eos> a . on a . <eos> a . <eos> a . on a . on a . on a . on a . on a . on a . on a . on a . on a . on
#
#
# 40% : minibatch_loss = 5.94652
# Image predictions
# plate: 0.311075
# restaurant: 0.225129
# dining_table: 0.204228
# crayfish: 0.0284817
# hot_pot: 0.0201128
# input: a man and a woman siting with a child around a table outside .
# output: a two man man is two of on is on of with on <eos> of <eos> on with <eos> on with <eos> on . <eos> . on <eos> . on <eos> . on <eos> . on <eos> . on <eos> . on <eos> . on a . on a . on
#
#
# WARNING:tensorflow:Error encountered when serializing __tensorboard_plugin_asset__tensorboard_text.
# Type is unsupported, or the types of the items don't match field type in CollectionDef.
# 'TextSummaryPluginAsset' object has no attribute 'name'
# checkpoint saved at 0822_021734/img2txt-40
# 41% : minibatch_loss = 6.09611
# Image predictions
# killer_whale: 0.486352
# breakwater: 0.130246
# lakeside: 0.114271
# grey_whale: 0.0528793
# seashore: 0.0317483
# input: a man surfing a wave in the ocean .
# output: a two man man is of of in on a of in a in of a in of a . in a . the a . on a . the a . on a . on a . on a . on a . on a . on a . on a . on
#
#
# 42% : minibatch_loss = 6.12391
# Image predictions
# four-poster: 0.985177
# screw: 0.00626847
# oboe: 0.00139851
# monastery: 0.00054961
# coil: 0.000283602
# input: a bed sitting in a bedroom next to a window .
# output: a two man man the is of the in of in the the . of . the <eos> . <eos> the . the <eos> . <eos> the . <eos> the . <eos> the <eos> . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 43% : minibatch_loss = 6.06736
# Image predictions
# rugby_ball: 0.835913
# parachute: 0.0227731
# soccer_ball: 0.011962
# basketball: 0.00618766
# football_helmet: 0.00549287
# input: a boy on the red team is about to kick the soccer ball .
# output: a two man man is of of in is a in of a in of in of a a in of a in of a in of in a <eos> in a of in a of a in <eos> a in of <eos> in a a . the a . the
#
#
# 44% : minibatch_loss = 5.80101
# Image predictions
# American_black_bear: 0.98106
# sloth_bear: 0.00223938
# vulture: 0.00106553
# schipperke: 0.00082654
# mongoose: 0.000694297
# input: two bear cubs running and playing in the wild .
# output: a two man man is the is a on a on in a on in a <eos> on <eos> a . <eos> a . <eos> . a <eos> a . <eos> a . a . the a . the a . the a . the a . the a . the a . the
#
#
# 45% : minibatch_loss = 5.91689
# Image predictions
# airliner: 0.960086
# wing: 0.00791583
# container_ship: 0.000800741
# space_shuttle: 0.000686723
# gibbon: 0.000474103
# input: an large commercial airplane parked in the airport .
# output: a two man man is of of a is of in on a of in a of in a . of . a of . a in . a of a . the a . the a . the a . the a . the a . the a . the
#
#
# 46% : minibatch_loss = 5.79169
# Image predictions
# pot: 0.133183
# vase: 0.122082
# teapot: 0.0515972
# mixing_bowl: 0.0305241
# caldron: 0.0245556
# input: a white table topped with multi colored vases under pictures .
# output: a two an man two is of in on in a of a in on a in of . a in . a in a . in . a in . a in <eos> . a a . on a . on a . on a . on
#
#
# 47% : minibatch_loss = 5.7801
# Image predictions
# plate_rack: 0.205388
# window_shade: 0.0893723
# stove: 0.0680955
# dining_table: 0.0463605
# dishwasher: 0.0437341
# input: this elegant bathroom has a marble counter on it
# output: a two an man two is a is with a on with a <eos> on a <eos> . a <eos> . a <eos> . <eos> a . <eos> a . a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 48% : minibatch_loss = 6.06422
# Image predictions
# toilet_seat: 0.743424
# barber_chair: 0.221591
# plunger: 0.00953817
# toilet_tissue: 0.00575719
# barbershop: 0.00466743
# input: a dirty lookin toilet is covered in <unk>
# output: a two man man two is of man is of on in of on and on of in on of and . on and . on of a . on a . on a . on a . on a . on a . on a . on
#
#
# 49% : minibatch_loss = 5.65228
# Image predictions
# cock: 0.899938
# hen: 0.0325717
# partridge: 0.00138416
# bobsled: 0.000649827
# barrow: 0.000406983
# input: a red white and black chicken standing in a field .
# output: a two an man is two a of in a in on a in on a . <eos> . <eos> a . <eos> a . a <eos> <eos> . a . <eos> a <eos> . a a . on a . on a . on a . on a . on a . on a . on
#
#
# 50% : minibatch_loss = 5.74844
# Image predictions
# bell_cote: 0.82545
# analog_clock: 0.0624365
# palace: 0.0216095
# wall_clock: 0.00833131
# monastery: 0.00826494
# input: a clocktower with a clear sky behind it .
# output: a two an man two is is of a a on of a on with a on in a on in a on in on a in <eos> a on a . on a . on a . on a . on a . on
#
#
# WARNING:tensorflow:Error encountered when serializing __tensorboard_plugin_asset__tensorboard_text.
# Type is unsupported, or the types of the items don't match field type in CollectionDef.
# 'TextSummaryPluginAsset' object has no attribute 'name'
# checkpoint saved at 0822_021734/img2txt-50
# 51% : minibatch_loss = 5.78186
# Image predictions
# lipstick: 0.0782522
# cellular_telephone: 0.0719743
# television: 0.050478
# lab_coat: 0.0342472
# face_powder: 0.0327563
# input: a man and a woman both holding their cell phones to their ears .
# output: a two an man woman an of in a of in a a of in a . of . <eos> a <eos> . a <eos> . a . <eos> a <eos> . a <eos> . a <eos> . a <eos> . a <eos> . a
#
#
# 52% : minibatch_loss = 5.8232
# Image predictions
# impala: 0.129545
# cheetah: 0.0792265
# gazelle: 0.0585564
# honeycomb: 0.0384575
# Arabian_camel: 0.0317805
# input: five giraffe stand around a pole eating hay .
# output: a two an man is of of is in a of in a of in a in of a in of a and in a in and . and the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 53% : minibatch_loss = 5.83243
# Image predictions
# greenhouse: 0.543287
# sliding_door: 0.0830035
# bathtub: 0.0189967
# carousel: 0.0111267
# patio: 0.00753834
# input: a woman trying to find a seat on a bus that is covered with plants .
# output: a two an man woman is of in the a of in a the of a . the <eos> a . . <eos> a . a <eos> . <eos> a . <eos> a . <eos> a . <eos> the . a <eos> . <eos> a . <eos> the <eos> . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 54% : minibatch_loss = 5.77623
# Image predictions
# racket: 0.770875
# ping-pong_ball: 0.026118
# volleyball: 0.0151058
# rugby_ball: 0.010824
# ballplayer: 0.0103643
# input: a woman hitting a ball with the tennis racket at the tennis court .
# output: a two an man is woman is of man of in a a of in a of in in on and a on and a and on a on the <eos> and on a and <eos> <eos> a and <eos> on and <eos> the and a . the
#
#
# 55% : minibatch_loss = 5.46739
# Image predictions
# quilt: 0.407064
# desk: 0.159486
# studio_couch: 0.0514487
# desktop_computer: 0.0348575
# sleeping_bag: 0.0195061
# input: a photo of a bedroom with a computer set up .
# output: a two an man woman a of with the a of with a with of a the with a <eos> the <eos> a . a <eos> . . <eos> a . <eos> a <eos> a . a . the a . the a . the a . the a . the a . the a . the
#
#
# 56% : minibatch_loss = 5.75708
# Image predictions
# bobsled: 0.706363
# mountain_bike: 0.0382957
# bannister: 0.0380363
# chain_saw: 0.025883
# ski: 0.0188274
# input: a boy riding a ramp using a skateboard with people watching near by .
# output: a two an man two woman of with the a with of a with the a the with a . the a <eos> the a . the a . <eos> . a the a . the . a the . a <eos> <eos> a . a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 57% : minibatch_loss = 5.77194
# Image predictions
# television: 0.640679
# safe: 0.0573357
# chest: 0.0558905
# crate: 0.0253431
# file: 0.0231748
# input: a child ina bed with a stuffed animal
# output: a two an man two woman of on with on of in on in with on in the <eos> the on . on the . <eos> on a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 58% : minibatch_loss = 5.41917
# Image predictions
# traffic_light: 0.536225
# pole: 0.0226934
# horizontal_bar: 0.0133014
# trolleybus: 0.0119307
# street_sign: 0.00862816
# input: a traffic light sitting on the corner of a street .
# output: a two an man woman a a of with a of on a of on a of on a on and a . of a . <eos> a <eos> . . a on <eos> a . a . the a . the a . the a . the a . the a . the
#
#
# 59% : minibatch_loss = 6.07519
# Image predictions
# monitor: 0.364574
# television: 0.311886
# screen: 0.135475
# laptop: 0.110788
# notebook: 0.0441798
# input: a cat looking at a picture of deers on a laptop screen
# output: two a an man woman is of on in of on in on of in of on in . on of <eos> . on . <eos> the . <eos> on <eos> . the . <eos> on . <eos> the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 60% : minibatch_loss = 5.60253
# Image predictions
# ski: 0.92839
# puck: 0.0124451
# snowmobile: 0.00307873
# alp: 0.00213218
# ski_mask: 0.00178324
# input: two children and an adult get off of a ski lift .
# output: a two an man is woman is of on is on of on of is on in of on of the on the a the on and <eos> the and . on the . <eos> the <eos> the and a . the a . the a . the a . the a . the a . the
#
#
# WARNING:tensorflow:Error encountered when serializing __tensorboard_plugin_asset__tensorboard_text.
# Type is unsupported, or the types of the items don't match field type in CollectionDef.
# 'TextSummaryPluginAsset' object has no attribute 'name'
# checkpoint saved at 0822_021734/img2txt-60
# 61% : minibatch_loss = 5.40549
# Image predictions
# Loafer: 0.117501
# running_shoe: 0.0933899
# Shetland_sheepdog: 0.0785509
# doormat: 0.0498156
# space_heater: 0.036271
# input: a little furry animal trying to fit into a shoe .
# output: a two an man woman is of a is a of on a of on a on of a of on a . of . a <eos> <eos> . a . a <eos> <eos> . a a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 62% : minibatch_loss = 5.57501
# Image predictions
# entertainment_center: 0.642787
# china_cabinet: 0.0931967
# home_theater: 0.0785974
# sliding_door: 0.00858925
# bookcase: 0.00830087
# input: a living room with red walls a chair and a television
# output: a two an man woman is is of and is on in on is in on the in on the in <eos> the of of the in . the <eos> <eos> . the . <eos> the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 63% : minibatch_loss = 5.21926
# Image predictions
# traffic_light: 0.933371
# spotlight: 0.00856881
# stage: 0.0048986
# projector: 0.00239503
# scoreboard: 0.00217131
# input: a top view of a city street with lights .
# output: a two an man woman a a of is a of on a on in a on in a on in a . on a . on . a <eos> <eos> a . a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 64% : minibatch_loss = 5.49855
# Image predictions
# toilet_seat: 0.554654
# washbasin: 0.259133
# toilet_tissue: 0.0625152
# bathtub: 0.0295392
# tub: 0.0233558
# input: a sink and toilet are in a white tiled public bathroom .
# output: a two an man is woman is of on on of in on in of on of in on in the <eos> the on on . of . <eos> on <eos> . the . the on <eos> . the a . the a . the a . the
#
#
# 65% : minibatch_loss = 5.44228
# Image predictions
# remote_control: 0.908264
# joystick: 0.0692958
# switch: 0.00307659
# mouse: 0.00139397
# hand-held_computer: 0.000411287
# input: a person holding on to a black remote
# output: a two an man woman two of in a a of in a in of a in of a <eos> in . <eos> a . a <eos> a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 66% : minibatch_loss = 5.48272
# Image predictions
# refrigerator: 0.92594
# perfume: 0.00254076
# lotion: 0.000891798
# nipple: 0.000875639
# medicine_chest: 0.00084243
# input: a photo of the inside of a white fridge .
# output: a two an man people woman of on with on in with on in with on in of on in the in on the . on in . <eos> the <eos> . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 67% : minibatch_loss = 5.48351
# Image predictions
# Indian_elephant: 0.753769
# African_elephant: 0.14677
# tusker: 0.0416658
# African_chameleon: 0.000565586
# water_buffalo: 0.000428022
# input: three elephants eating plants in an outdoor setting
# output: a two an man a woman a with is a with the a the with a the with a the . a . the . a <eos> a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 68% : minibatch_loss = 5.85071
# Image predictions
# fire_screen: 0.472333
# window_screen: 0.449245
# conch: 0.0385982
# Chihuahua: 0.0025864
# white_wolf: 0.00243289
# input: a group of cats sitting on the ground and on a shelf in a cage .
# output: two an a man woman people of the with of with the of the with the of with the of in <eos> . the . <eos> the . <eos> the . <eos> the <eos> . the . <eos> the . <eos> the <eos> . the . <eos> the <eos> . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 69% : minibatch_loss = 5.63611
# Image predictions
# seashore: 0.442592
# sandbar: 0.320583
# unicycle: 0.029912
# maillot: 0.0139371
# shovel: 0.00784583
# input: an image of a boy walking on the beach with surfboard
# output: a two an man people group of with is of with the of the with the of with of the with the a of the of with the of on the of a the of with a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 70% : minibatch_loss = 5.24741
# Image predictions
# ice_cream: 0.271181
# trifle: 0.271086
# chocolate_sauce: 0.0791484
# mixing_bowl: 0.022564
# bakery: 0.0182957
# input: a chocolate cake covered in white frosting sitting on a wooden table .
# output: a two an man people woman on and in a on in a on in a . on . a <eos> . a <eos> . a <eos> . a <eos> . <eos> a . <eos> a . <eos> a <eos> . a a . the a . the a . the a . the a . the a . the
#
#
# WARNING:tensorflow:Error encountered when serializing __tensorboard_plugin_asset__tensorboard_text.
# Type is unsupported, or the types of the items don't match field type in CollectionDef.
# 'TextSummaryPluginAsset' object has no attribute 'name'
# checkpoint saved at 0822_021734/img2txt-70
# 71% : minibatch_loss = 5.36861
# Image predictions
# moped: 0.437624
# mountain_bike: 0.174069
# bicycle-built-for-two: 0.0819673
# tricycle: 0.063292
# jinrikisha: 0.0163949
# input: few bicycles parked on the ground with a motorcycle .
# output: a two an man is woman on of is a on of a on of a on in a on the a on of <eos> on the a <eos> on <eos> a the a . the a . the a . the a . the a . the a . the a . the
#
#
# 72% : minibatch_loss = 5.24369
# Image predictions
# quilt: 0.458757
# sleeping_bag: 0.0758987
# Boston_bull: 0.0568702
# studio_couch: 0.0344052
# Chihuahua: 0.0157648
# input: a woman lounging in her bed with three cats .
# output: a two an man person woman of with is a of on a of on a of on of a <eos> a <eos> of . of <eos> <eos> . a <eos> . the a . the a . the a . the a . the a . the a . the
#
#
# 73% : minibatch_loss = 5.28927
# Image predictions
# freight_car: 0.95883
# passenger_car: 0.0128581
# steam_locomotive: 0.0042658
# electric_locomotive: 0.00128416
# mobile_home: 0.000816558
# input: an image of a train that is going down the track
# output: a two an is man people a with is a with in a in with a in with a in with a . <eos> a . <eos> a . in a . in . a <eos> a . the a . the a . the a . the
#
#
# 74% : minibatch_loss = 5.38939
# Image predictions
# dining_table: 0.186568
# quilt: 0.131626
# studio_couch: 0.106073
# bathtub: 0.0524841
# washbasin: 0.0506267
# input: an image of a bedroom setting on a high rise
# output: a an two man person group with of on on with of on with of on with of on of in on . the <eos> . on . on of . <eos> on a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 75% : minibatch_loss = 5.45587
# Image predictions
# banana: 0.916322
# orange: 0.0378914
# spaghetti_squash: 0.00986904
# lemon: 0.00872201
# pomegranate: 0.00276503
# input: a bowl of assorted fruits on a table .
# output: a an two man group person a of is a of is a of in a the in a of the a . <eos> a . the <eos> a the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 76% : minibatch_loss = 5.11606
# Image predictions
# suit: 0.694316
# Windsor_tie: 0.169747
# sunglasses: 0.0309837
# sunglass: 0.0159021
# Loafer: 0.00502261
# input: a <unk> red headed man is wearing sunglasses .
# output: a an two man is person is of with on of is with on in on with the on the with . on the . <eos> on <eos> . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 77% : minibatch_loss = 5.22776
# Image predictions
# water_bottle: 0.91465
# nipple: 0.0127083
# French_bulldog: 0.0093912
# water_jug: 0.00359601
# oxygen_mask: 0.00317452
# input: a person giving a dog a drink of water from a water bottle .
# output: a an two man a woman a on of a on in a on in a on in a on in a on in a on the a <eos> . a . on a <eos> . a . on a . the <eos> a . a . the a . the a . the a . the a . the a . the
#
#
# 78% : minibatch_loss = 5.88188
# Image predictions
# park_bench: 0.988348
# ashcan: 0.00115462
# sundial: 0.000701651
# rocking_chair: 0.000458168
# swing: 0.000415186
# input: two benches sitting next to each other next to a field .
# output: two an the man is of of is in in of on in of on in of on . <eos> in . in of . <eos> in . <eos> the . <eos> of . <eos> of <eos> . the a . the a . the a . the
#
#
# 79% : minibatch_loss = 6.01127
# Image predictions
# bicycle-built-for-two: 0.270445
# jinrikisha: 0.0971445
# tricycle: 0.0933654
# cash_machine: 0.037381
# minibus: 0.0251905
# input: a bicycle inside of a bicycle rack on a train .
# output: a two an man person woman on is of on with is on in with on with and on in with on in the on the in <eos> on the on <eos> the <eos> the on a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 80% : minibatch_loss = 5.54283
# Image predictions
# plate: 0.331317
# ice_cream: 0.079105
# burrito: 0.0509279
# hotdog: 0.0419223
# consomme: 0.0247107
# input: a small plate with a dessert and two spoons on it
# output: a two an man person group is of in in with on in the with the in with in of the the in . . <eos> the . of in . the <eos> . <eos> the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# WARNING:tensorflow:Error encountered when serializing __tensorboard_plugin_asset__tensorboard_text.
# Type is unsupported, or the types of the items don't match field type in CollectionDef.
# 'TextSummaryPluginAsset' object has no attribute 'name'
# checkpoint saved at 0822_021734/img2txt-80
# 81% : minibatch_loss = 5.30502
# Image predictions
# bookcase: 0.648161
# entertainment_center: 0.166346
# home_theater: 0.0228251
# tape_player: 0.0144263
# television: 0.0117732
# input: a television is near a wood book shelf
# output: a two an man person group in of is in on of a in on in a the in the on in a the the in <eos> a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 82% : minibatch_loss = 5.17938
# Image predictions
# Norfolk_terrier: 0.146721
# Lhasa: 0.117813
# Persian_cat: 0.107715
# cairn: 0.0739369
# Pekinese: 0.0614912
# input: dog appearing to be viewing television set on floor
# output: a two an person is man of a is a of with a of on a of on a of . a . of a . of . <eos> a a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 83% : minibatch_loss = 5.73706
# Image predictions
# desk: 0.367567
# iron: 0.208012
# waffle_iron: 0.0727811
# table_lamp: 0.0465029
# dining_table: 0.00986039
# input: a desk topped with a lamp and other items .
# output: two an the man person is is on in on in with on in with on in with on in with on in and on in and . on in <eos> the on a . the a . the a . the
#
#
# 84% : minibatch_loss = 5.56043
# Image predictions
# Indian_elephant: 0.966274
# tusker: 0.00470504
# African_elephant: 0.00152818
# African_chameleon: 0.000666525
# hook: 0.000221051
# input: an elephant walks eagerly toward an unknown destination .
# output: a two an man of person of with a a with of a . of . a of . a and . the of . <eos> and <eos> . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 85% : minibatch_loss = 5.59296
# Image predictions
# brown_bear: 0.796773
# teddy: 0.0111973
# ice_bear: 0.00703646
# American_black_bear: 0.00381335
# wombat: 0.00366996
# input: a big , brown bear walking in a clearing .
# output: a an two man person people of with is a with of a with of a with and a with and a the and a <eos> and a with and <eos> the and a . the a . the a . the a . the a . the a . the
#
#
# 86% : minibatch_loss = 5.33405
# Image predictions
# ice_bear: 0.674922
# ram: 0.188687
# bighorn: 0.05399
# marmot: 0.0228768
# ibex: 0.0182895
# input: the sheep are resting together on the rocks .
# output: a two an man is small of is and of on in on of in on in of a on the <eos> on of <eos> on the <eos> the and a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 87% : minibatch_loss = 5.36014
# Image predictions
# ballplayer: 0.857743
# baseball: 0.135463
# knee_pad: 0.0001549
# croquet_ball: 0.000153758
# plunger: 0.000116806
# input: a baseball player holding a bat approaching home plate .
# output: a two the man people young a of with a of with a in of a in and a in of a in of a in . a . in <eos> a the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 88% : minibatch_loss = 5.65026
# Image predictions
# parachute: 0.939596
# balloon: 0.0323417
# tricycle: 0.00903828
# unicycle: 0.00122667
# crutch: 0.00113361
# input: man with child flying kite over grassy field next to waterway .
# output: a two the man people are of in with in on and in on and on and in . the on . on the . on in . <eos> the . the on . <eos> the <eos> . the a . the a . the a . the a . the
#
#
# 89% : minibatch_loss = 5.24151
# Image predictions
# academic_gown: 0.248358
# mortarboard: 0.0956691
# garbage_truck: 0.084079
# ashcan: 0.0655386
# barrow: 0.0394291
# input: many people and tables outside flowers and buildings
# output: a two an man small is is on with a on in on in with on a in a on the a <eos> the the on a a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 90% : minibatch_loss = 5.40283
# Image predictions
# cheetah: 0.604731
# jaguar: 0.0777073
# leopard: 0.0527215
# gazelle: 0.0262766
# zebra: 0.0220076
# input: two giraffes on a field with trees and rock formations
# output: a an two man of woman of with and a of with a of and of and a a of and . a of . a of . a <eos> . a of a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# WARNING:tensorflow:Error encountered when serializing __tensorboard_plugin_asset__tensorboard_text.
# Type is unsupported, or the types of the items don't match field type in CollectionDef.
# 'TextSummaryPluginAsset' object has no attribute 'name'
# checkpoint saved at 0822_021734/img2txt-90
# 91% : minibatch_loss = 5.29798
# Image predictions
# pot: 0.412688
# altar: 0.150271
# greenhouse: 0.0324766
# restaurant: 0.0167117
# vase: 0.0134056
# input: a large floral arrangement outside a building .
# output: a two an man is person is of with with in is with in a in with on in on with on in and <eos> the and a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 92% : minibatch_loss = 5.24193
# Image predictions
# parachute: 0.944954
# balloon: 0.0209356
# sandbar: 0.00624792
# seashore: 0.0014836
# unicycle: 0.00134136
# input: a group of people in grassy area flying a kite .
# output: a the an man person group of with is a with of a on the a the on a . on a . the . a <eos> <eos> a . . <eos> a <eos> . a a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 93% : minibatch_loss = 5.27025
# Image predictions
# wok: 0.706375
# barrow: 0.0568352
# bucket: 0.0132554
# bassinet: 0.00910187
# mink: 0.00824457
# input: a dog laying in a dog bed with a stuffed animal
# output: the a two man is person of is with on is with the on in on in and on and in on and in the on and <eos> and the on and the on the and a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 94% : minibatch_loss = 5.60756
# Image predictions
# wreck: 0.997067
# vulture: 0.000157875
# cockroach: 6.68853e-05
# mobile_home: 1.98834e-05
# beach_wagon: 1.81762e-05
# input: a <unk> boat trapped on a sand bar near a house .
# output: a the two man a group a with is a in with a in with a the in a <eos> the . a in . a in a . <eos> <eos> . a . <eos> a <eos> . a a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 95% : minibatch_loss = 5.51768
# Image predictions
# carbonara: 0.578861
# plate: 0.0576437
# soup_bowl: 0.0538881
# cucumber: 0.0317952
# guacamole: 0.0281627
# input: various foods are cut up on a cutting board .
# output: two an the man is of is of with on with is on in with on in of the on in <eos> on . . <eos> on . <eos> on <eos> . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 96% : minibatch_loss = 5.62896
# Image predictions
# wall_clock: 0.883898
# analog_clock: 0.0568114
# barometer: 0.0074227
# sliding_door: 0.00107267
# vase: 0.000663228
# input: a clock with a plant in front of it .
# output: a the an man large group of is with of on with on the with on of the the on of . the on . the on . the <eos> <eos> . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 97% : minibatch_loss = 5.38476
# Image predictions
# ballplayer: 0.914102
# baseball: 0.0551091
# rugby_ball: 0.00313294
# parachute: 0.00289358
# soccer_ball: 0.00163465
# input: two baseball players in their athletic <unk> on the field .
# output: a an the man is person is with of is in with a in on in on a on in the a on in a the in <eos> the a . of on <eos> the . a . the a . the a . the a . the
#
#
# 98% : minibatch_loss = 5.17412
# Image predictions
# brassiere: 0.259525
# maillot: 0.140654
# bikini: 0.112142
# mask: 0.0349053
# bonnet: 0.0311803
# input: a woman is tying a tie around her neck .
# output: a an two man group woman of on is on of in a on in a on the of on a . on of . a the . a the <eos> . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 99% : minibatch_loss = 5.17534
# Image predictions
# picket_fence: 0.109279
# ostrich: 0.101562
# llama: 0.0777135
# Great_Dane: 0.0664099
# dalmatian: 0.0639453
# input: a baby giraffe learning how to stand up
# output: a two an man group large of with is of with a a in with a in the a in the a in of a . in a . the a . the a . the a . the a . the a . the a . the
#
#
# 100% : minibatch_loss = 5.12038
# Image predictions
# ox: 0.942627
# oxcart: 0.0311658
# Brittany_spaniel: 0.00146801
# worm_fence: 0.00066097
# water_buffalo: 0.000481733
# input: a brown and white cow with horns standing in a field .
# output: a two an man group large of in is in of with in on of in on of the a in . in on . in on . a the <eos> . the . <eos> of <eos> . the a . the a . the a . the a . the a . the a . the a . the
#
#
# WARNING:tensorflow:Error encountered when serializing __tensorboard_plugin_asset__tensorboard_text.
# Type is unsupported, or the types of the items don't match field type in CollectionDef.
# 'TextSummaryPluginAsset' object has no attribute 'name'
# checkpoint saved at 0822_021734/img2txt-100

# %% [markdown]
# ## Load a saved model and do an additional training.

# %%
img2txt = Image2Text(
    training_dataset=training_dataset,
    validation_dataset=validation_dataset,
    vocabulary_file_path='ms_coco_vocabulary.json',
    config_file_path='0822_021734/config.json',
    checkpoint_save_path='0822_021734/img2txt-100',
)
# Out:
# INFO:tensorflow:Restoring parameters from pretrained/inception_v3.ckpt
# INFO:tensorflow:Restoring parameters from 0822_021734/img2txt-100

# %%
rd = img2txt.train(
    additional_num_steps=100,
)
# Out:
# Training for 100 steps, total training 201 steps (= 0.015532 epochs).
# 0% : minibatch_loss = 5.19323
# Image predictions
# lakeside: 0.443298
# paddle: 0.246256
# seashore: 0.0399927
# breakwater: 0.037806
# sandbar: 0.0191409
# input: someone surfing waves on their surf board in the ocean
# output: a two an are group is are with is a are in a in the a in on a in on a in on a the in a <eos> the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# WARNING:tensorflow:Error encountered when serializing __tensorboard_plugin_asset__tensorboard_text.
# Type is unsupported, or the types of the items don't match field type in CollectionDef.
# 'TextSummaryPluginAsset' object has no attribute 'name'
# checkpoint saved at 0822_022050/img2txt-101
# 1% : minibatch_loss = 5.62502
# Image predictions
# steam_locomotive: 0.968069
# bib: 0.000701917
# marmot: 0.000342524
# electric_locomotive: 0.000334331
# passenger_car: 0.000294882
# input: a man walking by an old fashioned steam train
# output: two a the man group people of is in in on and in on and in and with in the and . in and . <eos> in . <eos> in a . the a . the a . the a . the a . the
#
#
# 2% : minibatch_loss = 4.93885
# Image predictions
# library: 0.348481
# laptop: 0.314758
# bookshop: 0.22174
# comic_book: 0.076369
# notebook: 0.020543
# input: a person using a laptop on the table at the library .
# output: a the an man group woman with of and with a on a with and with a and a the with the a and the and . a the and <eos> . the . <eos> the <eos> the and a . the a . the a . the
#
#
# 3% : minibatch_loss = 5.18204
# Image predictions
# gazelle: 0.0917414
# jaguar: 0.0861761
# cheetah: 0.0795021
# leopard: 0.065596
# impala: 0.03114
# input: a couple of large giraffes in side a fence
# output: a the two man woman group of with is a on the a on of a the on a the on a on . a <eos> the . <eos> of a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 4% : minibatch_loss = 5.02512
# Image predictions
# cheeseburger: 0.336994
# burrito: 0.214461
# plate: 0.0957691
# guacamole: 0.0388206
# consomme: 0.0165911
# input: a sandwich and vegetables are on a plate .
# output: a the two man large group of with in in of with in of with in on with a the in <eos> in the in of <eos> <eos> the a a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 5% : minibatch_loss = 5.15706
# Image predictions
# motor_scooter: 0.476689
# moped: 0.4053
# disk_brake: 0.0551848
# crash_helmet: 0.00219974
# car_wheel: 0.00137188
# input: a red harley davidson motorcycle parked on a street .
# output: a the two man large woman with a and a with on a on with a on with a on with a the on a . the . a on <eos> . a a . the a . the a . the a . the a . the a . the a . the
#
#
# 6% : minibatch_loss = 5.57244
# Image predictions
# acorn_squash: 0.707075
# spaghetti_squash: 0.138445
# fig: 0.0147947
# lemon: 0.0108953
# barrow: 0.00689237
# input: fruits and vegetables are in a bowl on a table .
# output: the two an man woman of of and in of in on of on in the of in <eos> and of . of and . the of <eos> . of . <eos> of <eos> . the a . the a . the a . the a . the
#
#
# 7% : minibatch_loss = 5.03582
# Image predictions
# tiger_cat: 0.094673
# cairn: 0.0806922
# Australian_terrier: 0.0735028
# Norwich_terrier: 0.0702758
# Irish_terrier: 0.0478392
# input: a cat that is sitting on a chair .
# output: a two the man woman person of in and in on with in on with in on the a the in <eos> in the . in on <eos> the table a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 8% : minibatch_loss = 5.35689
# Image predictions
# bathtub: 0.565456
# washbasin: 0.302777
# tub: 0.0635875
# soap_dispenser: 0.0239242
# medicine_chest: 0.00209959
# input: a sink ith soap and tooth brushes and tiled walls
# output: a two the man woman group of is sitting a on of a on of a on in on of a a . on a <eos> . . <eos> a . <eos> a a . the a . the a . the a . the a . the a . the
#
#
# 9% : minibatch_loss = 5.2976
# Image predictions
# orange: 0.893407
# lemon: 0.0352735
# strawberry: 0.0018714
# balance_beam: 0.00127748
# honeycomb: 0.000927117
# input: an orange peeled and cut , so the <unk> is removed .
# output: a two an man people is of is with on with in a the on on with in the a on the and of the <eos> a <eos> . and . the a . <eos> of <eos> . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 10% : minibatch_loss = 5.10403
# Image predictions
# moped: 0.390717
# motor_scooter: 0.379873
# crash_helmet: 0.0398385
# trombone: 0.00899431
# go-kart: 0.00323295
# input: a man is just getting onto his motorcycle and has his helmet in his hand .
# output: a an two man person woman a of is a on with a on with a on the a the and a . the a . <eos> a <eos> . . a <eos> . a <eos> . a <eos> a . the . a <eos> . a <eos> <eos> . a
#
#
# WARNING:tensorflow:Error encountered when serializing __tensorboard_plugin_asset__tensorboard_text.
# Type is unsupported, or the types of the items don't match field type in CollectionDef.
# 'TextSummaryPluginAsset' object has no attribute 'name'
# checkpoint saved at 0822_022050/img2txt-111
# 11% : minibatch_loss = 5.69034
# Image predictions
# airliner: 0.905713
# wing: 0.0174509
# space_shuttle: 0.0020065
# airship: 0.00186164
# aircraft_carrier: 0.00147804
# input: an airplane taking off from an airport .
# output: an two a man person group of is on on of in on in of on in of on in of . on in <eos> . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 12% : minibatch_loss = 5.44501
# Image predictions
# shopping_cart: 0.287791
# go-kart: 0.194313
# ashcan: 0.0817919
# breakwater: 0.0373501
# mobile_home: 0.026916
# input: a public transit bus on a city street
# output: a two an man person woman in of with in with on in with on the in with in <eos> and in of and in with of a . the a . the a . the a . the a . the
#
#
# 13% : minibatch_loss = 5.02511
# Image predictions
# paddle: 0.139185
# canoe: 0.116504
# swimming_trunks: 0.0431754
# bikini: 0.0315476
# speedboat: 0.0284646
# input: a man glides against a wave while surfing
# output: a two the man person woman of with in on with of on the with the a <eos> . on of . <eos> the . <eos> the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 14% : minibatch_loss = 5.16327
# Image predictions
# red_wine: 0.509017
# bubble: 0.0617197
# goblet: 0.0475891
# ladle: 0.0250215
# wok: 0.0157955
# input: a man sniffing some wine in a glass
# output: a the two man person woman of on is a on in a on the a on the a the on a the on of on in a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 15% : minibatch_loss = 5.20048
# Image predictions
# trolleybus: 0.82157
# passenger_car: 0.0575912
# school_bus: 0.0101156
# minibus: 0.00426882
# cab: 0.00170808
# input: a bus is moving along a busy city street .
# output: a two an man woman person of with is on with in a on with a on of a and the . of and . <eos> of . <eos> of <eos> a the a . the a . the a . the a . the a . the
#
#
# 16% : minibatch_loss = 4.84959
# Image predictions
# seashore: 0.759176
# dock: 0.0349094
# trimaran: 0.0234402
# sandbar: 0.023258
# catamaran: 0.0152637
# input: many small sail boats in a line on a beach .
# output: a two an man woman is is in with in on with in on a a the on <eos> a street on in of a the on <eos> a table <eos> . of <eos> a the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 17% : minibatch_loss = 5.0222
# Image predictions
# tabby: 0.250855
# tiger_cat: 0.220671
# motor_scooter: 0.21595
# moped: 0.0886468
# Egyptian_cat: 0.0500413
# input: a grey colored cat is laying on top of a blue suitcase .
# output: a the an man woman person of is with a in on a in on a on in a the on a the on . a on a the . . <eos> a . and of . a the <eos> . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 18% : minibatch_loss = 5.22749
# Image predictions
# bicycle-built-for-two: 0.334383
# tricycle: 0.154422
# mountain_bike: 0.0457868
# moped: 0.0392419
# tripod: 0.0360752
# input: a black and white photo of a dog sitting in a basket on a bicycle .
# output: a the two man woman person is of with is with in is on with on is in the a on and the of of on and on . and the a <eos> <eos> and . . <eos> and <eos> the . <eos> and . . <eos> of <eos> . it
#
#
# 19% : minibatch_loss = 4.99212
# Image predictions
# toyshop: 0.677588
# comic_book: 0.0814099
# refrigerator: 0.06287
# shoe_shop: 0.0229669
# china_cabinet: 0.0205487
# input: a fridge completely covered with pictures of dogs and some people
# output: a an two man woman group of in on a on in a on in a the on . on a a . <eos> . <eos> on . <eos> a . <eos> a . <eos> a a . the a . the a . the a . the a . the
#
#
# 20% : minibatch_loss = 5.2913
# Image predictions
# Indian_elephant: 0.75188
# tusker: 0.162574
# African_elephant: 0.0050566
# African_chameleon: 0.000409572
# stupa: 0.000352607
# input: two people are riding an elephant at a wildlife preserve .
# output: a two the man of is of is on on of in on of in on of in on of in on of in <eos> of table of on <eos> of on the <eos> table the a . the a . the a . the a . the a . the
#
#
# WARNING:tensorflow:Error encountered when serializing __tensorboard_plugin_asset__tensorboard_text.
# Type is unsupported, or the types of the items don't match field type in CollectionDef.
# 'TextSummaryPluginAsset' object has no attribute 'name'
# checkpoint saved at 0822_022050/img2txt-121
# 21% : minibatch_loss = 5.09331
# Image predictions
# quilt: 0.531835
# studio_couch: 0.0998707
# pillow: 0.0709998
# sleeping_bag: 0.0290432
# four-poster: 0.0274379
# input: a bed and a desk in a small room .
# output: a two there man young woman is with on a the is a table white on with a a the on a <eos> table a and on <eos> a the <eos> a the a . the a . the a . the a . the
#
#
# 22% : minibatch_loss = 5.30867
# Image predictions
# stage: 0.614426
# unicycle: 0.0650415
# Loafer: 0.0307852
# jean: 0.0214451
# cowboy_boot: 0.019991
# input: a boy on a skateboard does a trick in the hallway while other kids watch .
# output: a the an man woman people of is with the in a white with in of in on on in with the table <eos> of . and the . on <eos> the and . of and . <eos> of <eos> . the . <eos> of . <eos> the <eos> . table a . the a . the
#
#
# 23% : minibatch_loss = 4.95479
# Image predictions
# lakeside: 0.186841
# paddle: 0.0820867
# sandbar: 0.063129
# grey_whale: 0.052888
# swimming_trunks: 0.0386768
# input: a man riding a wave on a surfboard in the ocean .
# output: a an the man group woman of with and a on with a white table of on and a the an <eos> table a . of <eos> a the . . <eos> a . <eos> of <eos> . a a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 24% : minibatch_loss = 4.97553
# Image predictions
# yawl: 0.638484
# trimaran: 0.134507
# catamaran: 0.0544697
# dock: 0.00992247
# seashore: 0.00820577
# input: a boat sitting next to a blue boat on a sandy shore .
# output: a the an man group woman in of and in on with in on with the in on the table in in . of in . on the a in <eos> table the . in of . in the <eos> the table a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 25% : minibatch_loss = 4.95387
# Image predictions
# speedboat: 0.327639
# breakwater: 0.120902
# seashore: 0.0960841
# amphibian: 0.0822942
# lakeside: 0.0776177
# input: a surfer wearing a wet suit riding a wave .
# output: a the two man small woman of is sitting a on of a sitting white of a on a the on a the . a <eos> the . of <eos> <eos> a . a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 26% : minibatch_loss = 5.27476
# Image predictions
# analog_clock: 0.439625
# bell_cote: 0.365561
# wall_clock: 0.122425
# barometer: 0.00507161
# flagpole: 0.00326086
# input: a clock is sitting atop a tower that stands high in the city .
# output: a the two man woman small is on of on is with on the in on the in the table white on of in on the in the on <eos> <eos> the on the <eos> a <eos> the . . <eos> the <eos> the table a . the a . the a . the a . the a . the
#
#
# 27% : minibatch_loss = 4.8463
# Image predictions
# carousel: 0.439735
# umbrella: 0.0534937
# grocery_store: 0.0429322
# toyshop: 0.0312381
# confectionery: 0.0265679
# input: a group of people with several different umbrellas .
# output: a two the man woman small with is and a with the with in and a the with in with and . in with . a the <eos> . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 28% : minibatch_loss = 4.96111
# Image predictions
# swimming_trunks: 0.755393
# airship: 0.0386207
# missile: 0.0154194
# maillot: 0.00611569
# sandbar: 0.00557333
# input: a young man at the beach holding up his surfboard
# output: a the two man small woman of sitting is in on sitting a the in in the on on in of the a in . of the the <eos> . . <eos> the a . the a . the a . the a . the a . the
#
#
# 29% : minibatch_loss = 4.85747
# Image predictions
# home_theater: 0.929921
# entertainment_center: 0.0278508
# television: 0.0157403
# monitor: 0.00234048
# Loafer: 0.00213261
# input: showing the feet of a man who is watching tv
# output: a two the man is people with is on on with a a the with a with white on with . a on . a . on . on a . a <eos> a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 30% : minibatch_loss = 5.13504
# Image predictions
# mailbox: 0.269268
# water_jug: 0.0678102
# water_bottle: 0.0481302
# patio: 0.0426541
# ashcan: 0.0282955
# input: a fire hydrant painted white is on the side of the street beside a bush .
# output: a two the man small is is of sitting is of in the a on the in on the of in a the <eos> <eos> the of . of <eos> <eos> the a <eos> . of . <eos> of . <eos> of <eos> the a . <eos> of <eos> the . a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# WARNING:tensorflow:Error encountered when serializing __tensorboard_plugin_asset__tensorboard_text.
# Type is unsupported, or the types of the items don't match field type in CollectionDef.
# 'TextSummaryPluginAsset' object has no attribute 'name'
# checkpoint saved at 0822_022050/img2txt-131
# 31% : minibatch_loss = 4.74111
# Image predictions
# vase: 0.859222
# water_jug: 0.0179409
# restaurant: 0.0076089
# wine_bottle: 0.0068748
# cup: 0.00645391
# input: a few vases of red flowers set on tables .
# output: a two the man large couple is and on a on with a the white on and in on in a on in a a the on <eos> . on <eos> the a a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 32% : minibatch_loss = 5.13857
# Image predictions
# drum: 0.558864
# caldron: 0.194244
# bassoon: 0.0533079
# steel_drum: 0.0211659
# cello: 0.0209997
# input: a bunch of people playing with the nintendo wii .
# output: a the two man group large of is on a the people of on in on in the a the <eos> . <eos> the . the of . <eos> the <eos> the . a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 33% : minibatch_loss = 5.20284
# Image predictions
# umbrella: 0.985199
# kimono: 0.00225083
# sunglasses: 0.00210837
# parachute: 0.00072141
# sunglass: 0.000443504
# input: a woman with her yellow umbrella in a hot day .
# output: a two the man group large of and is a is white and of a a on with a on with a the on a white table of and in a of in <eos> a the a . the a . the a . the a . the a . the
#
#
# 34% : minibatch_loss = 5.07985
# Image predictions
# bell_cote: 0.907653
# dome: 0.00548289
# mosque: 0.00447658
# vault: 0.00372965
# beacon: 0.00306296
# input: a big building sits in the middle of a cement ground
# output: a the two man woman group with of is with in on in with on the a in the in and in of . a the <eos> <eos> the table <eos> . in <eos> . the a . the a . the a . the a . the
#
#
# 35% : minibatch_loss = 4.92523
# Image predictions
# tusker: 0.456038
# Indian_elephant: 0.447444
# African_elephant: 0.00206073
# hamper: 0.00129916
# triceratops: 0.000826625
# input: a elephant that is standing near a tree .
# output: a two an man group large of with in a on in a on in a in on a . in a <eos> white . of in <eos> a . a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 36% : minibatch_loss = 4.82877
# Image predictions
# teddy: 0.976864
# hand_blower: 0.00101333
# wig: 0.000841191
# ear: 0.000627292
# wool: 0.000559082
# input: a young woman holding a brown teddy bear .
# output: a two the man group people is with of is with in with a in white people man with in on on with in on in with <eos> the table a . the a . the a . the a . the a . the a . the a . the
#
#
# 37% : minibatch_loss = 5.01504
# Image predictions
# china_cabinet: 0.223168
# dining_table: 0.178468
# restaurant: 0.103435
# home_theater: 0.0420391
# sliding_door: 0.0343701
# input: a living room is ornately adorned with plush furniture .
# output: a two the group large people of is on on in a a on in a on in a . the a the . . <eos> of . a the <eos> . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 38% : minibatch_loss = 4.91755
# Image predictions
# barbershop: 0.202109
# pier: 0.128818
# patio: 0.0491122
# carton: 0.0328875
# dock: 0.0275913
# input: a man and a woman stand on the sidewalk lined with street lights .
# output: a two the man group woman with is of with the people white people with with on in on with in the a with <eos> with and <eos> with of <eos> the on <eos> the a <eos> . of <eos> . of <eos> the it a . the a . the a . the a . the
#
#
# 39% : minibatch_loss = 5.1552
# Image predictions
# modem: 0.557284
# radio: 0.14346
# mouse: 0.036121
# oscilloscope: 0.0320994
# joystick: 0.0253153
# input: these video game controllers are on the ground
# output: a the two man group is a on is a on in a on in a on in a the on . a <eos> . <eos> of a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 40% : minibatch_loss = 5.2325
# Image predictions
# pizza: 0.963391
# French_loaf: 0.000519187
# acorn_squash: 0.000345079
# tiger_cat: 0.00028816
# frying_pan: 0.000265725
# input: close up of a cheesy pizza with bits of broccoli in it .
# output: a two the is woman man on is in the standing in white table standing on of in on in of the <eos> in <eos> in of <eos> the in <eos> . in <eos> the in <eos> . in <eos> the table a . the a . the a . the a . the
#
#
# WARNING:tensorflow:Error encountered when serializing __tensorboard_plugin_asset__tensorboard_text.
# Type is unsupported, or the types of the items don't match field type in CollectionDef.
# 'TextSummaryPluginAsset' object has no attribute 'name'
# checkpoint saved at 0822_022050/img2txt-141
# 41% : minibatch_loss = 5.03228
# Image predictions
# ram: 0.848725
# bighorn: 0.0311518
# kelpie: 0.00327293
# kuvasz: 0.00153366
# llama: 0.0014035
# input: a ewe with her lambs relaxes in the green grass .
# output: a the two man woman person of is with a the people with on of on in of a on . a the . . <eos> of . of on . <eos> of <eos> . the a . the a . the a . the a . the a . the a . the
#
#
# 42% : minibatch_loss = 4.65624
# Image predictions
# bicycle-built-for-two: 0.584721
# crash_helmet: 0.0839255
# go-kart: 0.0210496
# moped: 0.0144859
# tricycle: 0.0109306
# input: three people riding skateboards down a hill next to grass .
# output: a the two man is group of with on a with on a on with a on in a table the of <eos> on . on <eos> a the <eos> <eos> . of <eos> table field a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 43% : minibatch_loss = 5.03745
# Image predictions
# water_buffalo: 0.43788
# African_elephant: 0.0888949
# bison: 0.0793585
# tusker: 0.0543649
# Indian_elephant: 0.0254819
# input: horses graze freely in the open field together
# output: a two the man group is with of is a with on a the an with a and . on with . a on . a <eos> a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 44% : minibatch_loss = 4.78149
# Image predictions
# streetcar: 0.322421
# freight_car: 0.143695
# trolleybus: 0.0215948
# bullet_train: 0.0129783
# passenger_car: 0.0120971
# input: a subway train gets ready to pass under ground
# output: a two the man woman group of is and is sitting in in on and in on with the a in in and on in the on <eos> the . a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 45% : minibatch_loss = 5.13207
# Image predictions
# laptop: 0.952601
# notebook: 0.00719335
# web_site: 0.00438003
# jigsaw_puzzle: 0.00420092
# joystick: 0.00414943
# input: people gather around a laptop on a mattress .
# output: a the two is man people a is of a the in a the white of in on a the in a table street . of in <eos> a the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 46% : minibatch_loss = 5.5987
# Image predictions
# zebra: 0.986874
# paddlewheel: 0.00557725
# African_elephant: 0.000277518
# hartebeest: 0.000187648
# impala: 0.000146761
# input: a couple of zebra grazing on a lush green hillside .
# output: there a the man woman group of is and the people is with of and on with in the a an street table and of and with in on of on and in <eos> table street a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 47% : minibatch_loss = 5.06122
# Image predictions
# African_elephant: 0.593335
# tusker: 0.346153
# Indian_elephant: 0.0139065
# ocarina: 0.000879176
# zebra: 0.000278814
# input: a close up profile of an elephant with short tusks
# output: a the two man woman group of with is in on with a the in a the an . in with . in on a the an . <eos> in . <eos> in a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 48% : minibatch_loss = 5.00282
# Image predictions
# cash_machine: 0.254277
# pay-phone: 0.129952
# sax: 0.0588297
# vending_machine: 0.0317256
# tobacco_shop: 0.015651
# input: a man smoking a cigarette on the street
# output: a an there man woman person of is with a on of a people an of with on a the an a the with of on with a . the a . the a . the a . the a . the a . the a . the
#
#
# 49% : minibatch_loss = 4.95907
# Image predictions
# English_setter: 0.159609
# Lakeland_terrier: 0.138991
# Bouvier_des_Flandres: 0.0688181
# German_short-haired_pointer: 0.0489269
# bluetick: 0.0403613
# input: a dog sits looking out the window during the day .
# output: a the an man woman group of is and on in is on a in on in the a the on . on of . a the a the <eos> . <eos> of <eos> . the a . the a . the a . the a . the
#
#
# 50% : minibatch_loss = 4.89087
# Image predictions
# soccer_ball: 0.166383
# ballplayer: 0.103922
# rugby_ball: 0.101983
# football_helmet: 0.0402513
# volleyball: 0.0307251
# input: keeper holding a soccer ball while other players walk around him .
# output: a the two man is are a of is a man white of with on on with a a the on a the on <eos> the a <eos> a the <eos> the . <eos> . the <eos> the street a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# WARNING:tensorflow:Error encountered when serializing __tensorboard_plugin_asset__tensorboard_text.
# Type is unsupported, or the types of the items don't match field type in CollectionDef.
# 'TextSummaryPluginAsset' object has no attribute 'name'
# checkpoint saved at 0822_022050/img2txt-151
# 51% : minibatch_loss = 4.99833
# Image predictions
# passenger_car: 0.862669
# bullet_train: 0.0456177
# streetcar: 0.0221453
# trolleybus: 0.0109436
# electric_locomotive: 0.00890853
# input: two white and black trains on tracks with bridge in the background .
# output: a the two is man group with of and a the with with on and on with in a the to . on and a the . . <eos> with a the . . <eos> street . <eos> of <eos> . the a . the a . the a . the a . the
#
#
# 52% : minibatch_loss = 4.88835
# Image predictions
# horse_cart: 0.320317
# plow: 0.112217
# worm_fence: 0.0522298
# rain_barrel: 0.0478623
# barrel: 0.0354489
# input: two people that are riding horses while people watch .
# output: a two the man woman is of with is a on in a on in a on in a on in a on in a on in <eos> a in <eos> street table a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 53% : minibatch_loss = 4.92114
# Image predictions
# Samoyed: 0.69315
# Great_Pyrenees: 0.0909419
# kuvasz: 0.0266358
# Pomeranian: 0.0123018
# chow: 0.0087641
# input: two fluffy white dogs on the side of the road , one with a leash attached .
# output: a two the group white people of in on a in on in on with a the an <eos> street a . <eos> of a <eos> the <eos> . street <eos> . of <eos> . a <eos> . of <eos> a . <eos> table street <eos> . of <eos> . of <eos> . street
#
#
# 54% : minibatch_loss = 5.05494
# Image predictions
# megalith: 0.199065
# hay: 0.169496
# golf_ball: 0.135366
# maze: 0.0653067
# stone_wall: 0.0507674
# input: sheep graze in a lush green pasture in front of houses .
# output: a two the is group man a on is a the people white man table on of in a on in a on the a the an . on of a the . . of in <eos> a . a . the a . the
#
#
# 55% : minibatch_loss = 4.85277
# Image predictions
# ox: 0.529408
# ram: 0.13081
# gazelle: 0.0470502
# ibex: 0.0273882
# sorrel: 0.0249775
# input: the cow is looking for some good food to eat ,
# output: a the two man woman group is with of on with is on in with on in the on in . . the on . <eos> the . the <eos> . <eos> of . <eos> the a . the a . the a . the a . the a . the a . the
#
#
# 56% : minibatch_loss = 4.75299
# Image predictions
# drake: 0.379705
# goose: 0.261304
# red-breasted_merganser: 0.0342609
# lakeside: 0.0161089
# American_coot: 0.0146743
# input: two ducks are swimming on the lake next to each other .
# output: a the two man woman is with is of a on with a the on a the an street table a . of with . of in a the . . <eos> of . <eos> of <eos> the a a . the a . the a . the a . the a . the
#
#
# 57% : minibatch_loss = 4.67333
# Image predictions
# bucket: 0.452282
# birdhouse: 0.10733
# crane: 0.0330313
# drum: 0.0312857
# coffee_mug: 0.0270952
# input: a kfc bucket sign atop a tall post .
# output: a the two man woman group of is and on in is on in the the in on the table street . of in . the on <eos> the table a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 58% : minibatch_loss = 4.95334
# Image predictions
# chain: 0.236367
# padlock: 0.0764068
# mailbox: 0.0614022
# sewing_machine: 0.0261206
# gas_pump: 0.0239726
# input: this photo depicts a red fire hydrant on the side walk .
# output: a two the is woman and a on is a on with a white table a on and a on in a . on a the an a . <eos> . <eos> on . a <eos> <eos> a . a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 59% : minibatch_loss = 5.32085
# Image predictions
# peacock: 0.725949
# indigo_bunting: 0.0443866
# worm_fence: 0.0116393
# shovel: 0.0114771
# rapeseed: 0.00911477
# input: a blue rusted fire hydrant sitting in the middle of a green field .
# output: the a two group man woman of with and with on in on with in on in with on in of the on in <eos> table street . <eos> of the <eos> it <eos> table street . <eos> of . of on <eos> . table a . the
#
#
# 60% : minibatch_loss = 5.01152
# Image predictions
# ox: 0.865253
# plow: 0.0314586
# oxcart: 0.0265317
# water_buffalo: 0.018916
# worm_fence: 0.010554
# input: a cow grazing in a field next to a fence .
# output: a the two man group woman is of with on in is a the in table street white . in on . on in the a . table street white . <eos> of <eos> . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# WARNING:tensorflow:Error encountered when serializing __tensorboard_plugin_asset__tensorboard_text.
# Type is unsupported, or the types of the items don't match field type in CollectionDef.
# 'TextSummaryPluginAsset' object has no attribute 'name'
# checkpoint saved at 0822_022050/img2txt-161
# 61% : minibatch_loss = 4.92303
# Image predictions
# trailer_truck: 0.906972
# moving_van: 0.0365774
# freight_car: 0.00424284
# forklift: 0.000885841
# garbage_truck: 0.000861014
# input: a large semi that is going down a concrete road .
# output: a two the man woman group is of and is with a in a with a to in on in to a on to a table street <eos> of and on <eos> a <eos> a the a . the a . the a . the a . the a . the a . the a . the
#
#
# 62% : minibatch_loss = 5.00425
# Image predictions
# Arabian_camel: 0.792547
# dogsled: 0.0322365
# sandbar: 0.0311428
# seashore: 0.00813522
# breakwater: 0.00468537
# input: a group of men riding horses as they travel along a beach .
# output: two a the man woman person of and in a the an of and in on in of on in of . <eos> a . <eos> a . <eos> on . of <eos> <eos> street table . <eos> of <eos> . street a . the a . the a . the
#
#
# 63% : minibatch_loss = 5.40999
# Image predictions
# tiger_cat: 0.329821
# tabby: 0.130485
# window_screen: 0.0566044
# Egyptian_cat: 0.0536905
# laptop: 0.028097
# input: an orange cat sitting on top of a window sill next to a bird .
# output: a the two man is and in and is a in on on in to a the an . on in a the an street table field . <eos> of . a <eos> . <eos> on a the . street a table . <eos> of <eos> . a a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 64% : minibatch_loss = 4.95147
# Image predictions
# moving_van: 0.797125
# trailer_truck: 0.0777963
# recreational_vehicle: 0.0135717
# police_van: 0.00597937
# garbage_truck: 0.00529129
# input: a white and green deliver truck with red trim .
# output: a the two man woman white and with is people is and with and in with in and in with on the a an and in with <eos> in and <eos> the field a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 65% : minibatch_loss = 4.88404
# Image predictions
# mashed_potato: 0.75748
# meat_loaf: 0.124226
# plate: 0.0207785
# acorn_squash: 0.00447868
# spatula: 0.00423943
# input: someone 's dinner consisting of brussel sprouts , and meat .
# output: a the two is man woman a of with a on in a on in a the an of on . . a on . a <eos> a the . . <eos> of <eos> . a a . the a . the a . the a . the a . the a . the
#
#
# 66% : minibatch_loss = 4.97323
# Image predictions
# patio: 0.311177
# sliding_door: 0.192971
# barber_chair: 0.162879
# barbershop: 0.0554668
# rocking_chair: 0.0129122
# input: living room scene with different types of brown furniture .
# output: a two the and of group of on in on in with the a an on of and on . in the a <eos> . <eos> and . <eos> on <eos> . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 67% : minibatch_loss = 4.79608
# Image predictions
# hotdog: 0.464931
# guacamole: 0.0369958
# groom: 0.0274965
# red_wine: 0.0242786
# cheeseburger: 0.0190628
# input: a woman is drinking beer and eating a hot dog .
# output: a two an man group woman of and in in on with on in a on in to a the an of in on a field table . <eos> of . <eos> on <eos> . field a . the a . the a . the a . the a . the
#
#
# 68% : minibatch_loss = 4.97042
# Image predictions
# crash_helmet: 0.982189
# motor_scooter: 0.00384251
# backpack: 0.00141625
# moped: 0.000595007
# disk_brake: 0.000396988
# input: a man riding on the back of a motorcycle .
# output: a two an man person group of with and a with on a the an table street field on with of a the an table field street . <eos> of <eos> . a a . the a . the a . the a . the a . the a . the a . the
#
#
# 69% : minibatch_loss = 4.39998
# Image predictions
# trolleybus: 0.752803
# passenger_car: 0.0302362
# school_bus: 0.0159081
# minibus: 0.0124462
# streetcar: 0.00162159
# input: there is a bicycle parked on the front of the red and white city bus .
# output: a two the of is man of with in white man a of in with in on of a the an table field street . of in a the <eos> <eos> table . . <eos> of <eos> a . . <eos> of . <eos> of . <eos> of <eos> . it a . the a . the a . the
#
#
# 70% : minibatch_loss = 4.89254
# Image predictions
# racket: 0.89801
# tennis_ball: 0.0837819
# volleyball: 0.00131696
# tray: 0.000819777
# miniskirt: 0.000656532
# input: a woman hitting a tennis ball with a racquet .
# output: a two the man person group of with and a with on white a man with in and in on with the a his table white field . <eos> in <eos> . the a . the a . the a . the a . the a . the a . the a . the
#
#
# WARNING:tensorflow:Error encountered when serializing __tensorboard_plugin_asset__tensorboard_text.
# Type is unsupported, or the types of the items don't match field type in CollectionDef.
# 'TextSummaryPluginAsset' object has no attribute 'name'
# checkpoint saved at 0822_022050/img2txt-171
# 71% : minibatch_loss = 4.86842
# Image predictions
# dock: 0.353971
# gondola: 0.0737775
# schooner: 0.0372965
# freight_car: 0.0223658
# pirate: 0.0191793
# input: an old sailing barge motors up a river past waterfront buildings .
# output: a two the man is person with is of a with on with on a with on a on with a a field table . <eos> with . a on . <eos> a . <eos> and <eos> . field a . the a . the a . the a . the a . the
#
#
# 72% : minibatch_loss = 4.74833
# Image predictions
# seat_belt: 0.995688
# minivan: 0.00105202
# limousine: 0.000766203
# Windsor_tie: 0.000723309
# minibus: 0.000149414
# input: man with glasses and a tie driving a car .
# output: a two an is of man a is people of a is a the white man white table of on and a on and a table white . <eos> of <eos> . a a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 73% : minibatch_loss = 4.68231
# Image predictions
# restaurant: 0.766828
# plate: 0.115602
# dining_table: 0.0338401
# menu: 0.0240024
# crayfish: 0.00326194
# input: a young girl and man eating food next to a window
# output: a two the person man group is of with on is in a the an on in of on a in on in a . on in a the . table field street . and of a . the a . the a . the a . the a . the
#
#
# 74% : minibatch_loss = 4.9448
# Image predictions
# alp: 0.677439
# ski: 0.234683
# mountain_tent: 0.0077493
# snowmobile: 0.00747909
# cliff: 0.00446557
# input: snowboarder wearing all green in the motion of jumping off a snow ramp .
# output: a two an is man person with in of in a with a in with a the an table white in in with of a the an . <eos> in . in <eos> <eos> a table <eos> . of . <eos> in <eos> a the a . the a . the a . the
#
#
# 75% : minibatch_loss = 4.74783
# Image predictions
# toilet_seat: 0.695403
# toilet_tissue: 0.0925512
# plunger: 0.0576252
# radio_telescope: 0.00442028
# spotlight: 0.00363377
# input: a toilet in a restroom has a newspaper on its tank .
# output: a the two man person large of is and a the an white large man of and on the on with table white street . of <eos> the a an . <eos> of . <eos> of <eos> . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 76% : minibatch_loss = 4.99416
# Image predictions
# umbrella: 0.948367
# park_bench: 0.00277174
# oxcart: 0.000976398
# jinrikisha: 0.000942316
# horse_cart: 0.000672602
# input: a man and a woman sitting and sharing an umbrella
# output: a two an man person group of is in a people is man white person in of on on in a a the an in on of a in on a in on a . the a . the a . the a . the a . the a . the
#
#
# 77% : minibatch_loss = 5.18636
# Image predictions
# mouse: 0.275086
# stethoscope: 0.246129
# joystick: 0.0509011
# iPod: 0.0439373
# screen: 0.0409703
# input: a boy in striped shirt playing a game with a nintendo wii controller .
# output: the an a man group person of and with the sitting of of and with <eos> on and <eos> on the <eos> table field <eos> . of <eos> the it <eos> table field . <eos> of <eos> . and <eos> . the <eos> . table a . the a . the a . the
#
#
# 78% : minibatch_loss = 4.70541
# Image predictions
# toyshop: 0.616362
# carousel: 0.114661
# chest: 0.0206965
# pencil_box: 0.017027
# altar: 0.013089
# input: a small display of tropical like <unk> <unk>
# output: a two an man group woman and with sitting in and on the a white and in with and on in and on in . and on a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 79% : minibatch_loss = 4.90014
# Image predictions
# notebook: 0.418769
# laptop: 0.12473
# projector: 0.118341
# mailbox: 0.0325171
# printer: 0.0248879
# input: a laptop on a bench with a cooler on a hand rail
# output: a an two person man group is of with a the an white table man with of in a the an table white street . of on a the an table field white . of on . a <eos> a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 80% : minibatch_loss = 4.70188
# Image predictions
# crash_helmet: 0.254167
# military_uniform: 0.199459
# ski_mask: 0.114515
# ski: 0.107758
# sunglass: 0.0797771
# input: a couple of people with snowboards in a room .
# output: a an the man person group of is with a the people on in of a the an on and of a the an table street field . and <eos> <eos> the . a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# WARNING:tensorflow:Error encountered when serializing __tensorboard_plugin_asset__tensorboard_text.
# Type is unsupported, or the types of the items don't match field type in CollectionDef.
# 'TextSummaryPluginAsset' object has no attribute 'name'
# checkpoint saved at 0822_022050/img2txt-181
# 81% : minibatch_loss = 4.99088
# Image predictions
# car_mirror: 0.99898
# loupe: 0.0001176
# baboon: 5.17543e-05
# fountain_pen: 4.9319e-05
# tiger_cat: 1.41189e-05
# input: a blue sky is reflected in a motorcycle rear view mirror .
# output: a two an man group black of with is on of in on in with on a in a the an table street white of . on . a on . a on . <eos> on <eos> a . a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 82% : minibatch_loss = 4.70473
# Image predictions
# tiger_cat: 0.358689
# Egyptian_cat: 0.252341
# tabby: 0.153657
# lynx: 0.0328413
# carton: 0.0109116
# input: a gray cat is sitting on a wooden bench
# output: a two the man woman group is with in in with is a in on in on with a the an table street field . <eos> in . <eos> in a . the a . the a . the a . the a . the a . the
#
#
# 83% : minibatch_loss = 4.88654
# Image predictions
# horse_cart: 0.958161
# plow: 0.0018137
# Arabian_camel: 0.000727512
# oxcart: 0.000566739
# dogsled: 0.000516842
# input: two horses pulling a carriage down a stone walkway .
# output: a two an is man woman is of with a on in a white people of in with a in the a table field . <eos> of . <eos> on <eos> . a a . the a . the a . the a . the a . the a . the
#
#
# 84% : minibatch_loss = 4.72983
# Image predictions
# ice_cream: 0.823466
# bakery: 0.0950276
# ice_lolly: 0.00846539
# pineapple: 0.00837294
# eggnog: 0.0072791
# input: the cake has different colors in it
# output: a two there man person woman is with in a is on on sitting in on to in a the an on of and a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 85% : minibatch_loss = 5.00822
# Image predictions
# ski: 0.470686
# reel: 0.0835887
# scuba_diver: 0.029295
# parachute: 0.0226511
# coho: 0.0176306
# input: skiing at night is always a bad idea for <unk> .
# output: a two there is of are a is on in a on a on in a on in a table field . <eos> of . <eos> a . <eos> a . <eos> a <eos> . a a . the a . the a . the a . the
#
#
# 86% : minibatch_loss = 4.91288
# Image predictions
# bakery: 0.789427
# grocery_store: 0.0542655
# butcher_shop: 0.0443328
# confectionery: 0.0178377
# restaurant: 0.00405448
# input: a woman in glasses is looking at a glass display of pastries .
# output: a two there woman person girl is of with the a people in with is in with on in on at the a an table street field <eos> in of <eos> in . the a <eos> <eos> . of <eos> table field a . the a . the
#
#
# 87% : minibatch_loss = 5.20918
# Image predictions
# paddle: 0.843426
# canoe: 0.119254
# tub: 0.00539312
# bathtub: 0.00327719
# clog: 0.00203583
# input: a man at the beach holding a cool surf board .
# output: a two the woman person large of in with a the with a table white in a with a the to a table field . <eos> of . a <eos> . a <eos> <eos> a . a . the a . the a . the a . the a . the
#
#
# 88% : minibatch_loss = 5.23889
# Image predictions
# photocopier: 0.420477
# binder: 0.117542
# printer: 0.0826374
# carton: 0.0666113
# safe: 0.0334407
# input: there is a man that is cutting a cake on a box
# output: two the a of is and on with in white table man of in with on in with on in of on in of table street field . <eos> of the . it table street field . <eos> of a . the a . the
#
#
# 89% : minibatch_loss = 4.90696
# Image predictions
# bobsled: 0.592864
# Band_Aid: 0.0206414
# steel_drum: 0.0176743
# drum: 0.0168054
# maillot: 0.0144095
# input: a man with a wax rub he 's putting on his surfboard .
# output: a the there woman man person of in with a people white table white man of on in on in with on in . . on <eos> . <eos> on the a . . <eos> of . <eos> of <eos> . field a . the a . the a . the
#
#
# 90% : minibatch_loss = 4.73204
# Image predictions
# sloth_bear: 0.479597
# American_black_bear: 0.422688
# wild_boar: 0.00469353
# chimpanzee: 0.00383286
# skunk: 0.00280521
# input: a black bear walking through a woody forest .
# output: a the two man woman group of with in in on with in on a a in on table man white in of with a in . <eos> a it a . the a . the a . the a . the a . the a . the
#
#
# WARNING:tensorflow:Error encountered when serializing __tensorboard_plugin_asset__tensorboard_text.
# Type is unsupported, or the types of the items don't match field type in CollectionDef.
# 'TextSummaryPluginAsset' object has no attribute 'name'
# checkpoint saved at 0822_022050/img2txt-191
# 91% : minibatch_loss = 4.9206
# Image predictions
# racket: 0.368415
# ballplayer: 0.158607
# soccer_ball: 0.055813
# golf_ball: 0.0202869
# croquet_ball: 0.0142174
# input: a boy about to hit a tennis ball .
# output: a the there man woman group of is with on a is a the on on a to a table field . of <eos> . <eos> on <eos> . a a . the a . the a . the a . the
#
#
# 92% : minibatch_loss = 4.80966
# Image predictions
# Indian_elephant: 0.95959
# tusker: 0.0260304
# African_elephant: 0.000678192
# hippopotamus: 0.000518267
# Mexican_hairless: 0.00026114
# input: a large gray elephant standing in front of a picture as it paints .
# output: a two an man woman group of is with of is with to on in to in on a the an of in to a the <eos> table field street <eos> of . <eos> . a <eos> . to <eos> a . <eos> a field a . the a . the a . the
#
#
# 93% : minibatch_loss = 4.59858
# Image predictions
# pizza: 0.519192
# burrito: 0.219104
# cheeseburger: 0.0775327
# hotdog: 0.0199482
# plate: 0.00688348
# input: a man is sitting at a table and eating pizza .
# output: a two the man woman group of is with a is in on in is a the an table field man . on of a the . . <eos> on . <eos> a <eos> . a a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 94% : minibatch_loss = 4.87642
# Image predictions
# water_buffalo: 0.465697
# bison: 0.12312
# African_elephant: 0.0378327
# Indian_elephant: 0.0171725
# baboon: 0.0116587
# input: a large group of elephants who are in the water .
# output: a two the man person woman is of with in is on a the an in with on on in with in on a a the an field table street in on of <eos> a the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 95% : minibatch_loss = 4.54215
# Image predictions
# bookcase: 0.431812
# library: 0.194925
# desktop_computer: 0.0739689
# file: 0.0353557
# desk: 0.0325478
# input: an office with a desk , bookshelves , computer , and laptop .
# output: a two the man woman person of and standing a the people table white field of and with a on and . a and . a and . <eos> a . <eos> a a . <eos> . <eos> of <eos> . it a . the a . the a . the a . the a . the a . the a . the a . the a . the a . the
#
#
# 96% : minibatch_loss = 4.8232
# Image predictions
# library: 0.34165
# bookshop: 0.292679
# shopping_cart: 0.0708008
# tobacco_shop: 0.0296112
# shoe_shop: 0.0155668
# input: a man standing in front of a table with lots of things .
# output: a two the man person woman of with in on in a a the an on in of a the an field table man <eos> on of a the an on and of a the it . of and <eos> field it a . the a . the a . the
#
#
# 97% : minibatch_loss = 4.50848
# Image predictions
# warthog: 0.14694
# bighorn: 0.128557
# gazelle: 0.0858098
# hog: 0.0281311
# park_bench: 0.0275566
# input: a sheep is <unk> its business near a body of water .
# output: a two an man person woman of with is in with sitting in a with a in and in and a a the <eos> field table street . <eos> of a <eos> the . <eos> of <eos> . it a . the
#
#
# 98% : minibatch_loss = 4.78505
# Image predictions
# snowmobile: 0.490885
# ski: 0.269488
# alp: 0.0702941
# dogsled: 0.0230066
# mountain_bike: 0.0178683
# input: a snowboarder is jumping near a wooded area .
# output: a two the man group young of is in in a is a in on a the in a table field of in . . a on <eos> a the a . the a . the a . the a . the a . the a . the
#
#
# 99% : minibatch_loss = 4.57387
# Image predictions
# moving_van: 0.348116
# tow_truck: 0.0915304
# trailer_truck: 0.0902985
# recreational_vehicle: 0.0896113
# passenger_car: 0.0332978
# input: a white bus is driving down a street .
# output: a an two man person woman with is standing with on is with on in with on and the with on table field street . <eos> with <eos> . field a . the a . the a . the a . the a . the a . the
#
#
# 100% : minibatch_loss = 4.90051
# Image predictions
# vase: 0.320899
# coffeepot: 0.140695
# pitcher: 0.0972693
# shower_curtain: 0.0553623
# water_jug: 0.0422169
# input: a orchid curves out its vase as it sits on table .
# output: a two an man person group of standing a a on in a on in a on in on of in a on in of on in . a of a the it . <eos> of <eos> . it a . the a . the a . the a . the a . the a . the a . the
#
#
# WARNING:tensorflow:Error encountered when serializing __tensorboard_plugin_asset__tensorboard_text.
# Type is unsupported, or the types of the items don't match field type in CollectionDef.
# 'TextSummaryPluginAsset' object has no attribute 'name'
# checkpoint saved at 0822_022050/img2txt-201
